# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('cleaned_marketing_customer_analysis.csv', index_col='Unnamed: 0')
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0           2/18/11         Employed      M   48029      Suburban
# 1           1/18/11       Unemployed      F       0      Suburban
# 2           2/10/11         Employed      M   22139      Suburban
# 3           1/11/11         Employed      M   49078      Suburban
# 4           2/14/11         Employed      F   37405         Urban
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
data.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
data['response'].value_counts().plot.bar()
plt.show()

# %%
data['response'] = data['response'].replace({'Yes': 1, 'No': 0})
data['response'].value_counts()
# Out:
# 0    7826
# 1    1308
# Name: response, dtype: int64

# %%
data1 = data.groupby(['sales_channel'])[['response']].sum()
data1['response_rate_by_sales_channel'] = data1['response'] / data['sales_channel'].value_counts()
sns.barplot(x=data1.index.values, y='response_rate_by_sales_channel', data=data1)
plt.xlabel('Sales Channel')
plt.title('Response Rate by Sales Channel')
plt.show()

# %%
data2 = data[['total_claim_amount','response']].sort_values('total_claim_amount')
data2
# Out:
#       total_claim_amount  response
# 3023            0.099007         0
# 3376            0.382107         0
# 5138            0.423310         0
# 6287            0.517753         0
# 8813            0.769185         0
# ...                  ...       ...
# 535          2345.413441         0
# 1070         2452.894264         0
# 8202         2552.343856         0
# 6543         2759.794354         0
# 3705         2893.239678         0
#
# [9134 rows x 2 columns]

# %%
data2_group = data2.groupby(pd.cut(data2['total_claim_amount'], 
                             bins=[0, 1000, 2000, 3000],  
                             labels=['low (0-1000)', 'medium (1000-2000)','high (2000-3000)']))['response'].agg(['size', 'sum']).reset_index()
data2_group['response_rate_by_total_claim_amount'] = data2_group['sum'] / data2_group['size']
data2_group
# Out:
#    total_claim_amount  size   sum  response_rate_by_total_claim_amount
# 0        low (0-1000)  8731  1248                             0.142939
# 1  medium (1000-2000)   384    60                             0.156250
# 2    high (2000-3000)    19     0                             0.000000

# %%
sns.barplot(x='total_claim_amount', y='response_rate_by_total_claim_amount', data=data2_group)
plt.xlabel('Total Claim Amount')
plt.title('Response Rate by Total Claim Amount')
plt.show()

# %%
data3 = data[['income','response']].sort_values('income')
data3
# Out:
#       income  response
# 7142       0         0
# 4124       0         0
# 2738       0         0
# 6644       0         0
# 5859       0         0
# ...      ...       ...
# 4999   99875         0
# 649    99934         0
# 4655   99960         0
# 8583   99961         0
# 8286   99981         0
#
# [9134 rows x 2 columns]

# %%
data3_group = data3.groupby(pd.cut(data3['income'], 
                             bins=[0, 20000, 40000, 60000, 80000, 100000]))['response'].agg(['size', 'sum']).reset_index()
data3_group['response_rate_by_income'] = data3_group['sum'] / data3_group['size']
data3_group
# Out:
#             income  size  sum  response_rate_by_income
# 0       (0, 20000]   522  162                 0.310345
# 1   (20000, 40000]  2274  408                 0.179420
# 2   (40000, 60000]  1540  192                 0.124675
# 3   (60000, 80000]  1457  234                 0.160604
# 4  (80000, 100000]  1024  114                 0.111328

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='income', y='response_rate_by_income', data=data3_group)
plt.xlabel('Income')
plt.title('Response Rate by Income')
plt.show()
